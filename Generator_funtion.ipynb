# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashant07-jaiswal/SD_PrashantJaiswal_0107/blob/main/Generator_funtion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "sudh"

# %%
type(s)
# Out:
# str

# %%
s1 = iter(s)

# %%
print(s1)

# %%
next(s1)
# Out:
# 's'

# %%
next(s1)
# Out:
# 'u'

# %%
next(s1)
# Out:
# 'd'

# %%
next(s1)
# Out:
# 'h'

# %%
def count_test(n):
  count = 1
  while count <= n:
    yield count
    count = count + 1

# %%
for i in count_test(3):
  print(i)
# Out:
# 1
# 2
# 3
