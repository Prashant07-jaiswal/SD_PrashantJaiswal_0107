# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashant07-jaiswal/SD_0107/blob/main/day_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [1,345,45,"sudh",True,5+7j,345.456]

# %%
l[5].real
# Out:
# 5.0

# %%
l[0:5:4]
# Out:
# [1, True]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 1

# %%
l[6]
# Out:
# 345.456

# %%
l[-1:-5:-2]
# Out:
# [345.456, True]

# %%
l[-1]
# Out:
# 345.456

# %%
l[3][0:2]
# Out:
# 'su'

# %%
s = "prashant"

# %%
list(s)+l
# Out:
# ['p',
#  'r',
#  'a',
#  's',
#  'h',
#  'a',
#  'n',
#  't',
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456]

# %%
l1 = [3,4,5]

# %%
l1+l
# Out:
# [3, 4, 5, 1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
l1*3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
len(l)
# Out:
# 7

# %%
s
# Out:
# 'prashant'

# %%
l.append(s)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 'prashant']

# %%
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_366/2311825727.py in <cell line: 0>()
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("sudh")

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 'prashant', 's', 'u', 'd', 'h']

# %%
print(l.extend(str(True)))
# Out:
# None

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  'prashant',
#  's',
#  'u',
#  'd',
#  'h',
#  'T',
#  'r',
#  'u',
#  'e']

# %%
l.append(l1)

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  'prashant',
#  's',
#  'u',
#  'd',
#  'h',
#  'T',
#  'r',
#  'u',
#  'e',
#  'T',
#  'r',
#  'u',
#  'e',
#  [3, 4, 5]]

# %%
l.extend([3,4,5])

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  'prashant',
#  's',
#  'u',
#  'd',
#  'h',
#  'T',
#  'r',
#  'u',
#  'e',
#  'T',
#  'r',
#  'u',
#  'e',
#  [3, 4, 5],
#  3,
#  4,
#  5]

# %%
l1.insert(2, [2,3,4])

# %%
l1
# Out:
# [3, 4, [2, 3, 4], 5]

# %%
l1.pop()
# Out:
# 5

# %%
l1.pop
# Out:
# <function list.pop(index=-1, /)>

# %%
l1.pop()
# Out:
# [2, 3, 4]

# %%
l.pop(3)
# Out:
# 'sudh'

# %%
l1.remove(3)

# %%
l1
# Out:
# [4]

# %%
l
# Out:
# [1,
#  345,
#  45,
#  True,
#  (5+7j),
#  345.456,
#  'prashant',
#  's',
#  'u',
#  'd',
#  'h',
#  'T',
#  'r',
#  'u',
#  'e',
#  'T',
#  'r',
#  'u',
#  'e',
#  [4],
#  3,
#  4,
#  5]

# %%
l.remove(3)

# %%
l
# Out:
# [1,
#  345,
#  45,
#  True,
#  (5+7j),
#  345.456,
#  'prashant',
#  's',
#  'u',
#  'd',
#  'h',
#  'T',
#  'r',
#  'u',
#  'e',
#  'T',
#  'r',
#  'u',
#  'e',
#  [4],
#  4,
#  5]

# %%
l.pop(3)
# Out:
# True

# %%
l2 = [45,23,90,0,3,4,5,6,7,8,9]

# %%
l2.sort()

# %%
l2
# Out:
# [0, 3, 4, 5, 6, 7, 8, 9, 23, 45, 90]

# %%
t = (2,3,4,5,"sudh",45.56,False,45+45j,[3,4,5])

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+45j), [3, 4, 5])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [3, 4, 5]

# %%
t.append(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_366/134011257.py in <cell line: 0>()
# ----> 1 t.append(2)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t*3
# Out:
# (2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+45j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+45j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+45j),
#  [3, 4, 5])

# %%
s1 ={}

# %%
type(s1)
# Out:
# dict

# %%
s2 = {2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
s3 = {324,456,456,"sudh",45+45j,34.456,(3,4,5)}

# %%
s3
# Out:
# {(3, 4, 5), (45+45j), 324, 34.456, 456, 'sudh'}

# %%
s3
# Out:
# {(3, 4, 5), (45+45j), 324, 34.456, 456, 'sudh'}

# %%
s5 = {12,23,234,342,45,456,567,789,"abc"}

# %%
s5.add(4)

# %%
s5
# Out:
# {12, 23, 234, 342, 4, 45, 456, 567, 789, 'abc'}

# %%
s5[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_366/182782020.py in <cell line: 0>()
# ----> 1 s5[::-1]
#
# TypeError: 'set' object is not subscriptable

# %%
s5.remove(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_366/3651126432.py in <cell line: 0>()
# ----> 1 s5.remove(2)
#
# KeyError: 2

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d1 = {'key':"sudh"}

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
d2 = {'name':"sudhanshu","email":"james.s.sherman@example-pet-store.com","number":334534}

# %%
d3 = {234:"sudh",'_wer':"kumar",True:1234}

# %%
d3[234]
# Out:
# 'sudh'

# %%
d3[True]
# Out:
# 1234

# %%
d3[1]
# Out:
# 1234
